# %%
library(tidyverse)

# %%
incident = read.csv("./NIBRS_month.csv")
offense = read.csv("./NIBRS_OFFENSE.csv")
offender = read.csv("./NIBRS_OFFENDER.csv")
victim = read.csv("./NIBRS_VICTIM.csv")

# %%
head(offense)
# Out:
#   data_year offense_id incident_id offense_code attempt_complete_flag
# 1 2022      181625733  151569497   23H          C
# 2 2022      182978559  152750784   13B          C
# 3 2022      185931304  155326464   240          C
# 4 2022      187690885  156857304   13B          C
# 5 2022      196068971  164157796   26B          C
# 6 2022      185929400  155324870   240          C
#   location_id num_premises_entered method_entry_code
# 1 25          NA
# 2 40          NA
# 3 25          NA
# 4 35          NA
# 5 35          NA
# 6 25          NA

# %%
offense_type = read.csv("./Codes/NIBRS_OFFENSE_TYPE.csv")
offense_type %>%
    filter(offense_code == "240")
# Out:
#   offense_code offense_name        crime_against ct_flag hc_flag hc_code
# 1 240          Motor Vehicle Theft Property      t       t       7
#   offense_category_name offense_group
# 1 Motor Vehicle Theft   A

# %%
car_theft_id = offense %>%
    filter(offense_code == "240") %>%
    select(incident_id)

# %%
car_theft_victim = victim %>%
    filter(incident_id %in% car_theft_id[,1])
head(car_theft_victim)
# Out:
#   data_year victim_id incident_id victim_seq_num victim_type_id
# 1 2022      171606164 155326464   1              4
# 2 2022      171604258 155324870   1              4
# 3 2022      170501644 154371166   1              4
# 4 2022      165003174 149544227   1              4
# 5 2022      165003175 149544227   2              4
# 6 2022      165003176 149544227   3              8
#   assignment_type_id activity_type_id outside_agency_id age_id age_num sex_code
# 1 NA                 NA               NA                 48    45      M
# 2 NA                 NA               NA                 89    86      M
# 3 NA                 NA               NA                 59    56      F
# 4 NA                 NA               NA                 59    56      F
# 5 NA                 NA               NA                 60    57      M
# 6 NA                 NA               NA                104    NS      X
#   race_id ethnicity_id resident_status_code age_range_low_num
# 1 20      20                                45
# 2 20      20           R                    86
# 3 20      20           N                    56
# 4 20      40                                56
# 5 20      20                                57
# 6 99      50                                NA
#   age_code_range_high
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA

# %%
car_theft_victim %>%
    ggplot(aes(x = as.factor(race_id))) +
    geom_bar()
# Out:
# plot without title

# %%
car_theft_victim %>%
    ggplot(aes(x = as.numeric(age_num))) +
    geom_histogram(bins = 10)
# Out:
# Warning message in FUN(X[[i]], ...):
# "NAs introduced by coercion"
# Warning message in FUN(X[[i]], ...):
# "NAs introduced by coercion"
# Warning message:
# "Removed 261 rows containing non-finite values (`stat_bin()`)."
# plot without title

# %%
offense %>%
    filter(incident_id %in% car_theft_id[,1]) %>%
    merge(car_theft_victim, by = "incident_id") %>%
    filter(sex_code %in% c("F", "M")) %>%
    ggplot(aes(x = as.factor(location_id))) +
    geom_bar() +
    facet_grid(~sex_code)
# Out:
# plot without title

# %%
offense %>%
    filter(incident_id %in% car_theft_id[,1]) %>%
    merge(car_theft_victim, by = "incident_id") %>%
    filter(sex_code %in% c("F", "M")) %>%
    count(location_id, sex_code) %>%
    filter(n > 50) %>%
    ggplot(aes(x = as.factor(location_id), y = n)) +
    geom_bar(stat = "identity") +
    facet_grid(~sex_code)
# Out:
# plot without title

# %%
location_type = read.csv("./Codes/NIBRS_LOCATION_TYPE.csv")
location_type %>%
    filter(location_id %in% c(25, 33, 35, 37, 41, 98))
# Out:
#   location_id location_code location_name
# 1 25          13            Highway/Road/Alley/Street/Sidewalk
# 2 33          18            Parking/Drop Lot/Garage
# 3 35          20            Residence/Home
# 4 37          21            Restaurant
# 5 41          23            Service/Gas Station
# 6 98          25            Other/Unknown
